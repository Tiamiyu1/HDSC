# %% [markdown]
# <a href="https://colab.research.google.com/github/Tiamiyu1/HDSC/blob/main/1.%20Hamoye_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]

col = ['Age', 'Nationality','Overall']

# %%
df = pd.DataFrame(lst, columns=col, index=[1,2,3])

# %%
df.iloc[:]
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %%
array  = ([[94, 89, 63],

             [93, 92, 48],

             [92, 94, 56]])

# %%
S = [['him', 'sell'], [90, 28, 43]]

S[0][1][1]
# Out:
# 'e'

# %%
my_tuppy = (1,2,5,8)

my_tuppy[2] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-ce1543b3be47> in <module>()
#       1 my_tuppy = (1,2,5,8)
#       2
# ----> 3 my_tuppy[2] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %%
y = [(2, 4), (7, 8), (1, 5, 9)]

# %%
y[1][-2]
# Out:
# 7

# %%
path = "https://github.com/HamoyeHQ/HDSC-Introduction-to-Python-for-machine-learning/files/7768140/FoodBalanceSheets_E_Africa_NOFLAG.csv"
food = pd.read_csv(path, encoding = "ISO-8859-1")

# %%
food.head()
# Out:
#    Area Code     Area  Item Code  ...     Y2016     Y2017     Y2018
# 0          4  Algeria       2501  ...  40551.00  41389.00  42228.00
# 1          4  Algeria       2501  ...      0.00      0.00      0.00
# 2          4  Algeria       2901  ...   3372.00   3341.00   3322.00
# 3          4  Algeria       2901  ...     94.72     92.82     91.83
# 4          4  Algeria       2901  ...     77.40     80.19     77.28
#
# [5 rows x 12 columns]

# %%
food.groupby('Item')[['Y2014', 'Y2017']].sum()
# Out:
#                          Y2014      Y2017
# Item
# Alcohol, Non-Food      2403.00    2348.00
# Alcoholic Beverages  102410.11   95581.06
# Animal Products       11935.65   11547.65
# Animal fats          209460.54  269617.53
# Apples and products    9499.23   10198.90
# ...                        ...        ...
# Vegetables, Other    155038.96  157752.59
# Vegetal Products     107145.19  107655.20
# Wheat and products   232670.13  240047.62
# Wine                   4497.36    4178.02
# Yams                 200396.96  229174.59
#
# [119 rows x 2 columns]

# %%
food.describe()
# Out:
#           Area Code     Item Code  ...          Y2017          Y2018
# count  60943.000000  60943.000000  ...   59437.000000   59507.000000
# mean     134.265576   2687.176706  ...     140.917765     143.758381
# std       72.605709    146.055739  ...    1671.862359    1710.782658
# min        4.000000   2501.000000  ...   -1582.000000   -3396.000000
# 25%       74.000000   2562.000000  ...       0.000000       0.000000
# 50%      136.000000   2630.000000  ...       0.100000       0.070000
# 75%      195.000000   2775.000000  ...       9.000000       9.000000
# max      276.000000   2961.000000  ...  190873.000000  195875.000000
#
# [8 rows x 8 columns]

# %%
import seaborn as sns

# %%
food.corr()
# Out:
#               Area Code  Item Code  Element Code  ...     Y2016     Y2017     Y2018
# Area Code      1.000000  -0.005159     -0.000209  ...  0.005247  0.005006  0.005665
# Item Code     -0.005159   1.000000     -0.024683  ...  0.020109  0.021494  0.021314
# Element Code  -0.000209  -0.024683      1.000000  ...  0.023444  0.024254  0.024279
# Y2014          0.006164   0.021722      0.024457  ...  0.996081  0.995230  0.994872
# Y2015          0.005472   0.020857      0.023889  ...  0.995739  0.988048  0.988208
# Y2016          0.005247   0.020109      0.023444  ...  1.000000  0.992785  0.992757
# Y2017          0.005006   0.021494      0.024254  ...  0.992785  1.000000  0.998103
# Y2018          0.005665   0.021314      0.024279  ...  0.992757  0.998103  1.000000
#
# [8 rows x 8 columns]

# %%
food.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
food.isnull().sum()/food.shape[0]*100
# Out:
# Area Code       0.000000
# Area            0.000000
# Item Code       0.000000
# Item            0.000000
# Element Code    0.000000
# Element         0.000000
# Unit            0.000000
# Y2014           2.607354
# Y2015           2.540078
# Y2016           2.518747
# Y2017           2.471162
# Y2018           2.356300
# dtype: float64

# %%
food.groupby('Element').sum()
# Out:
#                                         Area Code  ...       Y2018
# Element                                            ...
# Domestic supply quantity                   708993  ...  2161192.10
# Export Quantity                            599910  ...   181594.80
# Fat supply quantity (g/capita/day)         675050  ...    10258.69
# Feed                                       176272  ...   233489.68
# Food                                       663295  ...  1303841.28
# Food supply (kcal/capita/day)              674057  ...   455261.00
# Food supply quantity (kg/capita/yr)        658446  ...    49056.85
# Import Quantity                            688174  ...   287997.09
# Losses                                     274353  ...   163902.00
# Other uses (non-food)                      235554  ...    91300.97
# Processing                                 271940  ...   308429.00
# Production                                 526751  ...  2075072.89
# ...

# %%
aa = food.groupby('Element')[['Element', 'Y2018']] .sum()

# %%
aa.sort_values(by='Y2018')
# Out:
#                                              Y2018
# Element
# Tourist consumption                          90.00
# Fat supply quantity (g/capita/day)        10258.69
# Protein supply quantity (g/capita/day)    11833.56
# Stock Variation                           20577.91
# Seed                                      25263.14
# Residuals                                 34864.00
# Food supply quantity (kg/capita/yr)       49056.85
# Other uses (non-food)                     91300.97
# Losses                                   163902.00
# Export Quantity                          181594.80
# Feed                                     233489.68
# Import Quantity                          287997.09
# Processing                               308429.00
# Food supply (kcal/capita/day)            455261.00
# Total Population - Both sexes           1140605.00
# Food                                    1303841.28
# Production                              2075072.89
# ...

# %%
food.head(2)
# Out:
#    Area Code     Area  Item Code  ...    Y2016    Y2017    Y2018
# 0          4  Algeria       2501  ...  40551.0  41389.0  42228.0
# 1          4  Algeria       2501  ...      0.0      0.0      0.0
#
# [2 rows x 12 columns]

# %%
food.groupby(['Element','Area'])['Y2018'].sum()
# Out:
# Element                   Area
# Domestic supply quantity  Algeria                  90023.42
#                           Angola                   59590.22
#                           Benin                    31447.90
#                           Botswana                  3045.85
#                           Burkina Faso             25705.16
#                                                      ...
# Tourist consumption       Cabo Verde                   7.00
#                           Egypt                       23.00
#                           Kenya                       17.00
#                           Mauritius                   31.00
#                           Sao Tome and Principe       12.00
# Name: Y2018, Length: 803, dtype: float64

# %%
area['Y2018'].sum()
# Out:
# Area
# Algeria                         341729.98
# Angola                          235206.68
# Benin                           124960.70
# Botswana                         23129.08
# Burkina Faso                    112970.72
# Cabo Verde                       14622.60
# Cameroon                        233022.93
# Central African Republic         30101.57
# Chad                             72282.24
# Comoros                             59.84
# Congo                            42005.53
# Côte d'Ivoire                   227018.00
# Djibouti                         23718.96
# Egypt                           852652.92
# Eswatini                         55045.07
# Ethiopia                        450788.86
# Ethiopia PDR                         0.00
# Gabon                            28339.38
# Gambia                           23513.80
# Ghana                           358915.64
# Guinea                          103262.08
# Guinea-Bissau                    18997.92
# ...

# %%
food.Element.unique()
# Out:
# array(['Total Population - Both sexes', 'Domestic supply quantity',
#        'Food supply (kcal/capita/day)',
#        'Protein supply quantity (g/capita/day)',
#        'Fat supply quantity (g/capita/day)', 'Production',
#        'Import Quantity', 'Stock Variation', 'Export Quantity', 'Feed',
#        'Seed', 'Losses', 'Processing', 'Other uses (non-food)',
#        'Residuals', 'Food', 'Food supply quantity (kg/capita/yr)',
#        'Tourist consumption'], dtype=object)

# %%
area[['Y2018', 'Element']].sum()
# Out:
#                                   Y2018
# Area
# Algeria                       341729.98
# Angola                        235206.68
# Benin                         124960.70
# Botswana                       23129.08
# Burkina Faso                  112970.72
# Cabo Verde                     14622.60
# Cameroon                      233022.93
# Central African Republic       30101.57
# Chad                           72282.24
# Comoros                           59.84
# Congo                          42005.53
# Côte d'Ivoire                 227018.00
# Djibouti                       23718.96
# Egypt                         852652.92
# Eswatini                       55045.07
# Ethiopia                      450788.86
# Ethiopia PDR                       0.00
# Gabon                          28339.38
# Gambia                         23513.80
# Ghana                         358915.64
# Guinea                        103262.08
# Guinea-Bissau                  18997.92
# ...

# %%
food.Area.nunique()
# Out:
# 49
